# %% [markdown]
# #**Import packages**

# %%
# %env SCIPY_ARRAY_API=1
import pandas as pd
import numpy as np
import requests
import zipfile
from io import BytesIO
# !pip install combat
# !pip install combat --upgrade
# !pip install inmoose
from inmoose.pycombat import pycombat_norm, pycombat_seq
from combat.pycombat import pycombat
from sklearn.model_selection import train_test_split
# !pip install conorm
import conorm as conorm
from sklearn.preprocessing import LabelEncoder
from conorm import tmm_norm_factors
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.feature_selection import mutual_info_classif
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
from sklearn.feature_selection import RFECV
# !pip install rnanorm
# !pip install mrmr_selection
from mrmr import mrmr_classif
# !pip install imbalanced-learn
import os
import random
import numpy as np
seed = 40
random.seed(seed)
np.random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
# Out:
# env: SCIPY_ARRAY_API=1
# Collecting combat
#   Downloading combat-0.3.3.tar.gz (34 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.12/dist-packages (from combat) (2.0.2)
# Requirement already satisfied: mpmath>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from combat) (1.3.0)
# Requirement already satisfied: pandas>=0.24.2 in /usr/local/lib/python3.12/dist-packages (from combat) (2.2.2)
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from combat) (1.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.24.2->combat) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.24.2->combat) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.24.2->combat) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=0.24.2->combat) (1.17.0)
# Building wheels for collected packages: combat
#   Building wheel for combat (setup.py) ... done
#   Created wheel for combat: filename=combat-0.3.3-py3-none-any.whl size=36781 sha256=f2795f5da99abae0a1bec88f3226ffe6897b163869c23ad9222ebf9b666d5c4f
#   Stored in directory: /root/.cache/pip/wheels/1c/da/80/1de8f643b1d0f625ccf140689db76f17b0d85e0364aa971e32
# Successfully built combat
# Installing collected packages: combat
# Successfully installed combat-0.3.3
# Requirement already satisfied: combat in /usr/local/lib/python3.12/dist-packages (0.3.3)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.12/dist-packages (from combat) (2.0.2)
# Requirement already satisfied: mpmath>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from combat) (1.3.0)
# Requirement already satisfied: pandas>=0.24.2 in /usr/local/lib/python3.12/dist-packages (from combat) (2.2.2)
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from combat) (1.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.24.2->combat) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.24.2->combat) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.24.2->combat) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=0.24.2->combat) (1.17.0)
# Collecting inmoose
#   Downloading inmoose-0.9.0.tar.gz (7.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 48.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting anndata (from inmoose)
#   Downloading anndata-0.12.3-py3-none-any.whl.metadata (9.9 kB)
# Collecting fastcluster (from inmoose)
#   Downloading fastcluster-1.3.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.7 kB)
# Requirement already satisfied: mpmath>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from inmoose) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from inmoose) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from inmoose) (2.2.2)
# Requirement already satisfied: patsy in /usr/local/lib/python3.12/dist-packages (from inmoose) (1.0.2)
# Requirement already satisfied: scipy>=1.16.0 in /usr/local/lib/python3.12/dist-packages (from inmoose) (1.16.2)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (from inmoose) (0.13.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from inmoose) (1.6.1)
# Requirement already satisfied: statsmodels>=0.14.5 in /usr/local/lib/python3.12/dist-packages (from inmoose) (0.14.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from inmoose) (3.10.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from inmoose) (3.1.6)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.12/dist-packages (from statsmodels>=0.14.5->inmoose) (25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->inmoose) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->inmoose) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->inmoose) (2025.2)
# Collecting array-api-compat>=1.7.1 (from anndata->inmoose)
#   Downloading array_api_compat-1.12.0-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: h5py>=3.8 in /usr/local/lib/python3.12/dist-packages (from anndata->inmoose) (3.15.1)
# Collecting legacy-api-wrap (from anndata->inmoose)
#   Downloading legacy_api_wrap-1.4.1-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: natsort in /usr/local/lib/python3.12/dist-packages (from anndata->inmoose) (8.4.0)
# Collecting zarr!=3.0.*,>=2.18.7 (from anndata->inmoose)
#   Downloading zarr-3.1.3-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->inmoose) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->inmoose) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->inmoose) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->inmoose) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->inmoose) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->inmoose) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->inmoose) (3.2.5)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->inmoose) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->inmoose) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->inmoose) (1.17.0)
# Collecting donfig>=0.8 (from zarr!=3.0.*,>=2.18.7->anndata->inmoose)
#   Downloading donfig-0.8.1.post1-py3-none-any.whl.metadata (5.0 kB)
# Collecting numcodecs>=0.14 (from numcodecs[crc32c]>=0.14->zarr!=3.0.*,>=2.18.7->anndata->inmoose)
#   Downloading numcodecs-0.16.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.3 kB)
# Requirement already satisfied: typing-extensions>=4.9 in /usr/local/lib/python3.12/dist-packages (from zarr!=3.0.*,>=2.18.7->anndata->inmoose) (4.15.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from donfig>=0.8->zarr!=3.0.*,>=2.18.7->anndata->inmoose) (6.0.3)
# Collecting crc32c>=2.7 (from numcodecs[crc32c]>=0.14->zarr!=3.0.*,>=2.18.7->anndata->inmoose)
#   Downloading crc32c-2.8-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (7.8 kB)
# Downloading anndata-0.12.3-py3-none-any.whl (169 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.3/169.3 kB 13.3 MB/s eta 0:00:00
# Downloading fastcluster-1.3.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 11.8 MB/s eta 0:00:00
# Downloading array_api_compat-1.12.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.2/58.2 kB 3.4 MB/s eta 0:00:00
# Downloading zarr-3.1.3-py3-none-any.whl (276 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 276.4/276.4 kB 17.4 MB/s eta 0:00:00
# Downloading legacy_api_wrap-1.4.1-py3-none-any.whl (10.0 kB)
# Downloading donfig-0.8.1.post1-py3-none-any.whl (21 kB)
# Downloading numcodecs-0.16.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 73.0 MB/s eta 0:00:00
# Downloading crc32c-2.8-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (80 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.0/80.0 kB 6.8 MB/s eta 0:00:00
# Building wheels for collected packages: inmoose
#   Building wheel for inmoose (pyproject.toml) ... done
#   Created wheel for inmoose: filename=inmoose-0.9.0-cp312-cp312-linux_x86_64.whl size=5066909 sha256=14327a5b5958ce1d6ae3ba010dc68d1937d15fbc1632ab32a283e8e0bd9c4e9b
#   Stored in directory: /root/.cache/pip/wheels/97/74/fc/c782b9c33af30a04e5e3337369120a928b3508bee0c745e3dc
# Successfully built inmoose
# Installing collected packages: numcodecs, legacy-api-wrap, fastcluster, donfig, crc32c, array-api-compat, zarr, anndata, inmoose
# Successfully installed anndata-0.12.3 array-api-compat-1.12.0 crc32c-2.8 donfig-0.8.1.post1 fastcluster-1.3.0 inmoose-0.9.0 legacy-api-wrap-1.4.1 numcodecs-0.16.3 zarr-3.1.3
# Collecting conorm
#   Downloading conorm-1.2.0.tar.gz (5.6 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from conorm) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from conorm) (2.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->conorm) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->conorm) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->conorm) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->conorm) (1.17.0)
# Building wheels for collected packages: conorm
#   Building wheel for conorm (setup.py) ... done
#   Created wheel for conorm: filename=conorm-1.2.0-py3-none-any.whl size=5770 sha256=a70b8f53100a5e1d0a5547a60e6391d91742ed1086857c266067ea3bdd66b4f6
#   Stored in directory: /root/.cache/pip/wheels/c8/b8/ca/ea244434880ff1f1ab371b346f727bfac5786dd4974f198066
# Successfully built conorm
# Installing collected packages: conorm
# Successfully installed conorm-1.2.0
# Collecting rnanorm
#   Downloading rnanorm-2.2.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from rnanorm) (8.3.0)
# Requirement already satisfied: numpy>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from rnanorm) (2.0.2)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from rnanorm) (2.2.2)
# Requirement already satisfied: scikit-learn>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from rnanorm) (1.6.1)
# Collecting pandera (from rnanorm)
#   Downloading pandera-0.26.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.0->rnanorm) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.0->rnanorm) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.0->rnanorm) (2025.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.6.0->rnanorm) (1.16.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.6.0->rnanorm) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.6.0->rnanorm) (3.6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from pandera->rnanorm) (25.0)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.12/dist-packages (from pandera->rnanorm) (2.11.10)
# Requirement already satisfied: typeguard in /usr/local/lib/python3.12/dist-packages (from pandera->rnanorm) (4.4.4)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.12/dist-packages (from pandera->rnanorm) (4.15.0)
# Collecting typing_inspect>=0.6.0 (from pandera->rnanorm)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.0->rnanorm) (1.17.0)
# Collecting mypy-extensions>=0.3.0 (from typing_inspect>=0.6.0->pandera->rnanorm)
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic->pandera->rnanorm) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic->pandera->rnanorm) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic->pandera->rnanorm) (0.4.2)
# Downloading rnanorm-2.2.0-py3-none-any.whl (124 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.6/124.6 kB 4.8 MB/s eta 0:00:00
# Downloading pandera-0.26.1-py3-none-any.whl (292 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 292.9/292.9 kB 11.6 MB/s eta 0:00:00
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Installing collected packages: mypy-extensions, typing_inspect, pandera, rnanorm
# Successfully installed mypy-extensions-1.1.0 pandera-0.26.1 rnanorm-2.2.0 typing_inspect-0.9.0
# Collecting mrmr_selection
#   Downloading mrmr_selection-0.2.8-py3-none-any.whl.metadata (6.6 kB)
# Collecting category-encoders (from mrmr_selection)
#   Downloading category_encoders-2.8.1-py3-none-any.whl.metadata (7.9 kB)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from mrmr_selection) (3.1.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from mrmr_selection) (4.67.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from mrmr_selection) (1.5.2)
# Requirement already satisfied: pandas>=1.0.3 in /usr/local/lib/python3.12/dist-packages (from mrmr_selection) (2.2.2)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.12/dist-packages (from mrmr_selection) (2.0.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from mrmr_selection) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mrmr_selection) (1.16.2)
# Requirement already satisfied: polars>=0.12.5 in /usr/local/lib/python3.12/dist-packages (from mrmr_selection) (1.25.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.3->mrmr_selection) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.3->mrmr_selection) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.3->mrmr_selection) (2025.2)
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from category-encoders->mrmr_selection) (1.0.2)
# Requirement already satisfied: statsmodels>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from category-encoders->mrmr_selection) (0.14.5)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->mrmr_selection) (3.6.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->mrmr_selection) (3.0.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.3->mrmr_selection) (1.17.0)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.12/dist-packages (from statsmodels>=0.9.0->category-encoders->mrmr_selection) (25.0)
# Downloading mrmr_selection-0.2.8-py3-none-any.whl (15 kB)
# Downloading category_encoders-2.8.1-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.7/85.7 kB 3.1 MB/s eta 0:00:00
# Installing collected packages: category-encoders, mrmr_selection
# Successfully installed category-encoders-2.8.1 mrmr_selection-0.2.8
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.12/dist-packages (0.14.0)
# Requirement already satisfied: numpy<3,>=1.25.2 in /usr/local/lib/python3.12/dist-packages (from imbalanced-learn) (2.0.2)
# Requirement already satisfied: scipy<2,>=1.11.4 in /usr/local/lib/python3.12/dist-packages (from imbalanced-learn) (1.16.2)
# Requirement already satisfied: scikit-learn<2,>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from imbalanced-learn) (1.6.1)
# Requirement already satisfied: joblib<2,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from imbalanced-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from imbalanced-learn) (3.6.0)

# %% [markdown]
# #**Load data**

# %%
sample_url = "https://raw.githubusercontent.com/MyronBest/InTVeld_Pancancer_TSOO/main/TableS2.csv"

sampleinfo = pd.read_csv(sample_url)
sampleinfo.drop('Unnamed: 0', axis=1, inplace=True)

sampleinfo=sampleinfo[(sampleinfo['Group']=='Ovarian cancer')|(sampleinfo['Group']=='Asymptomatic controls')]

sampleinfo=sampleinfo.loc[sampleinfo['Sex']=='F']

sampleinfo = sampleinfo[~((sampleinfo['Group'] == 'Ovarian cancer') & (sampleinfo['Stage'] == 'n.a.'))]

sampleinfo['Stage']=sampleinfo['Stage'].replace(to_replace='n.a.',value='Control')

# %%
order = ["Institute 1", "Institute 2", "Institute 3", "Institute 4", "Institute 5",
                "Institute 10", "Institute 12", "Institute 13"]

sampleinfo = sampleinfo.sort_values(by="Sample.supplying.institution").reset_index(drop=True)

Samples=sampleinfo['Sample.ID'].tolist()

# %%
# !pip install pyreadr
import pyreadr
import requests
import io
import tempfile

reads="https://raw.githubusercontent.com/ShaimaaGG/TEP_Ovarian-Cancer/main/dat/GSE183635_TEP_Count_Matrix.RData"

response = requests.get(reads)
response.raise_for_status()
with tempfile.NamedTemporaryFile(suffix=".RData") as tmp:
    tmp.write(response.content)
    tmp.flush()
    result = pyreadr.read_r(tmp.name)

counts=list(result.values())[0]
print(counts.shape)
# Out:
# Requirement already satisfied: pyreadr in /usr/local/lib/python3.12/dist-packages (0.5.3)
# Requirement already satisfied: pandas>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from pyreadr) (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.2.0->pyreadr) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.2.0->pyreadr) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.2.0->pyreadr) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.2.0->pyreadr) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.2.0->pyreadr) (1.17.0)

# %%
genes="https://raw.githubusercontent.com/ShaimaaGG/TEP_Ovarian-Cancer/main/dat/dgeGenesEnsembl75.RData"

response = requests.get(genes)
response.raise_for_status()
with tempfile.NamedTemporaryFile(suffix=".RData") as tmp:
    tmp.write(response.content)
    tmp.flush()
    result = pyreadr.read_r(tmp.name)

genes=list(result.values())[0]
genes.index.name = None
print(genes.shape)
# Out:
# (57736, 9)

# %%
counts.columns = counts.columns.str.replace(r'^.*?-', '', regex=True)
counts=counts[Samples]
y_genes=genes[genes['chromosome_name']=='Y']
y_genes=y_genes['ensembl_gene_id'].tolist()
print(len(y_genes))
genes_in_counts=counts.index.tolist()
matching_y = list(set(y_genes).intersection(genes_in_counts))
counts=counts.drop(matching_y)
print(counts.shape)
# Out:
# 495
# (5434, 355)

# %%
genes.set_index(genes['ensembl_gene_id'], inplace=False)
genes_in_counts=counts.index.tolist()
mask = genes['ensembl_gene_id'].isin(genes_in_counts)
genes_in_counts=genes[mask]

# %%
print(genes_in_counts.shape)
print(counts.shape)
# Out:
# (5434, 9)
# (5434, 355)

# %% [markdown]
# #**RLE plot before batch correction**

# %%
RLE=counts.copy()
medians=RLE.median(axis=1)
RLE=np.log2(RLE + 1).sub(np.log2(medians + 1), axis=0)
plt.figure(figsize=(15,15))
sns.boxplot(data=RLE, showfliers=False)
plt.ylabel("Relative Log Expression (RLE)")
plt.title("RLE before batch correction")
plt.xticks([])
plt.gca().xaxis.set_ticks_position('none')
plt.tight_layout()
plt.axhline(0, color='black', linestyle='-', linewidth=0.5)
plt.show()

# %% [markdown]
# #**Batch Effect Correction**
#
# InMoose provides features to correct technical biases, also called batch effects, in transcriptomic data
#
# ***for RNASeq***, InMoose features a port to Python3 of ComBat-Seq, one of the most widely used tool for batch effect correction on RNASeq data.
# To use these functions, simply import them and call them with default parameters:
#
# **##ComBat-seq and pyComBat (pycombat_seq)**
# both work on data that follow a negative binomial distribution, which is the distribution of raw counts in RNA-Seq data. No preprocessing of the raw counts is thus needed.
# https://doi.org/10.1186/s12859-023-05578-5

# %%
corrected = pycombat_seq(counts, sampleinfo['Sample.supplying.institution'])
corrected=pd.DataFrame(corrected, columns=Samples, index=genes_in_counts['ensembl_gene_id'])
corrected=corrected.transpose()

# %%
from rnanorm import TMM
tmm = TMM().fit(corrected)
tmm.get_norm_factors(corrected)
norm=tmm.transform(corrected)
norm=pd.DataFrame(data=norm, columns=genes_in_counts['ensembl_gene_id'])
Encoder=LabelEncoder()
norm.insert(5434, 'Stage', value=sampleinfo['Stage'])
norm['Stage']=Encoder.fit_transform(norm['Stage'])

# %% [markdown]
# #**RLE plot after batch correction**

# %%
RLE=norm.iloc[:, :-1].transpose()
medians=RLE.median(axis=1)
RLE=np.log2(RLE + 1).sub(np.log2(medians + 1), axis=0)
plt.figure(figsize=(15,15))
sns.boxplot(data=RLE, showfliers=False)
plt.ylabel("Relative Log Expression (RLE)")
plt.title("RLE after batch correction")
plt.xticks([])
plt.gca().xaxis.set_ticks_position('none')
plt.tight_layout()
plt.axhline(0, color='black', linestyle='-', linewidth=0.5)
plt.show()

# %% [markdown]
# #**Apply variance threshold**

# %%
from sklearn.feature_selection import VarianceThreshold
selector = VarianceThreshold(threshold=0)
selector.fit_transform(norm.iloc[:,:-1])
selector.get_support()
var_selected=list(selector.get_feature_names_out())
var_selected=norm.loc[:,var_selected]
var_selected.set_index(sampleinfo['Sample.ID'],inplace=True)

# %% [markdown]
# #**Split and transform Labels**

# %%
StageI_samples=sampleinfo.copy()
StageI_samples['Stage'] = StageI_samples['Stage'].replace(['II', 'III', 'IV'], 'rest')
StageI_samples=StageI_samples[StageI_samples['Stage'] != 'rest']
StageI_IDs=StageI_samples['Sample.ID'].tolist()
StageI_samples['Stage']=Encoder.fit_transform(StageI_samples['Stage'])
y=StageI_samples['Stage'].to_numpy()
X=var_selected.loc[StageI_IDs].to_numpy()

# %% [markdown]
# #**Stage 1 versus control**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(StageI_samples['Stage'])
plt.title('Number of Samples in Control and Stage I')
plt.show()

# %%
print(X.shape)
classes, counts = np.unique(y, return_counts=True)
print(f"classes: {classes}")
print(f"Counts: {counts}")
# Out:
# (253, 5434)
# classes: [0 1]
# Counts: [217  36]

# %% [markdown]
# #**Apply SMOTE**

# %%
from imblearn.over_sampling import SMOTE
from sklearn.preprocessing import StandardScaler
Scaler=StandardScaler()
sm = SMOTE(random_state=40, sampling_strategy='minority')
X_res, y_res = sm.fit_resample(X, y)
X_train, X_test, y_train, y_test = train_test_split(X_res, y_res,
                                                    test_size=0.1, random_state=40, stratify=y_res)
X_train=Scaler.fit_transform(X_train)
X_test=Scaler.transform(X_test)

# %%
print(X_res.shape)
classes, counts = np.unique(y_res, return_counts=True)
print(f"classes: {classes}")
print(f"Counts: {counts}")
# Out:
# (434, 5434)
# classes: [0 1]
# Counts: [217 217]

# %% [markdown]
# #**SelectFromModel-SVM**

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import LinearSVC
param_grid = {'C': [0.01, 0.1, 1, 10, 100]}
grid_search = GridSearchCV(LinearSVC(random_state=40), param_grid, scoring='accuracy', cv=5)
grid_search.fit(X_train, y_train)
grid_search.best_estimator_
# Out:
# LinearSVC(C=0.01, random_state=40)

# %%
from sklearn.feature_selection import SelectFromModel
from sklearn.svm import LinearSVC
from sklearn.metrics import accuracy_score
SVC=LinearSVC(C=0.01, class_weight='balanced', random_state=40)
SVC.fit(X_train, y_train)
sfm = SelectFromModel(SVC, prefit=True, max_features=500)
sfm_selected=sfm.get_support(indices=True)
sfm_selected=[var_selected.columns[i] for i in sfm_selected]
print(len(sfm_selected))
# Out:
# 500

# %%
url = "https://raw.githubusercontent.com/ShaimaaGG/Machine-learning-course/main/dat/Differential_exp_results.xlsx"
DEGs = pd.read_excel(url, sheet_name="AUC_validation_dataset")
DEGs=DEGs[DEGs['Stage'] == 'Stage1']
DEGs=DEGs['ensembl_gene_id'].tolist()
common= list(set(DEGs).intersection(sfm_selected))
print("Common items:", len(common))

# %% [markdown]
# #**Venn Diagrm**

# %%
# !pip install matplotlib-venn matplotlib
from matplotlib_venn import venn3
import matplotlib.pyplot as plt
# !pip install venny4py
# Out:
# Requirement already satisfied: matplotlib-venn in /usr/local/lib/python3.12/dist-packages (1.1.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from matplotlib-venn) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from matplotlib-venn) (1.15.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.60.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.2.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Collecting venny4py
#   Downloading venny4py-1.0.3-py3-none-any.whl.metadata (1.8 kB)
# Downloading venny4py-1.0.3-py3-none-any.whl (4.5 kB)
# Installing collected packages: venny4py
# Successfully installed venny4py-1.0.3

# %%
from venny4py.venny4py import venny4py
import matplotlib.pyplot as plt
from PIL import Image

DEGs = set(DEGs)
sfm_selected = set(sfm_selected)

sets = {
    'SSCs': DEGs,
    'ML-Selected genes': sfm_selected
}

venny4py(sets=sets, size=2, dpi=600, out='Stage 1', ext='png', font_size=6)

img = Image.open("/content/Stage 1/Venn_2.png")

fig, ax = plt.subplots(figsize=(4, 4), dpi=300)
ax.imshow(img)
ax.axis('off')
ax.text(0.5, 0.95, 'Stage 1', transform=ax.transAxes, ha='center', fontsize=11)


plt.savefig("Stage_1.png", dpi=300, bbox_inches='tight', pad_inches=0)
plt.show()

# %%
X=var_selected.loc[StageI_IDs, common].to_numpy()
from imblearn.over_sampling import SMOTE
from sklearn.preprocessing import StandardScaler
Scaler=StandardScaler()
sm = SMOTE(random_state=40, sampling_strategy='minority')
X_res, y_res = sm.fit_resample(X, y)
X_train, X_test, y_train, y_test = train_test_split(X_res, y_res,
                                                    test_size=0.1, random_state=40, stratify=y_res)
X_train=Scaler.fit_transform(X_train)
X_test=Scaler.transform(X_test)

# %% [markdown]
# #**Test on RF**

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [10, 20, 50],
    'min_samples_split': [2, 5, 10]
}

RF = RandomForestClassifier(random_state=40)

grid_search = GridSearchCV(RF, param_grid, scoring='accuracy', cv=5)
grid_search.fit(X_train, y_train)

print(grid_search.best_estimator_)
# Out:
# RandomForestClassifier(max_depth=10, n_estimators=50, random_state=40)

# %%
RF=RandomForestClassifier(max_depth=10,n_estimators=50,random_state=40)
RF=RF.fit(X_train, y_train)
print(accuracy_score(y_train, RF.predict(X_train)))
print(accuracy_score(y_test, RF.predict(X_test)))
# Out:
# 1.0
# 0.9318181818181818

# %%
from sklearn.metrics import accuracy_score, precision_score,classification_report, recall_score, f1_score, confusion_matrix
y_test_pred = RF.predict(X_test)
accuracy = accuracy_score(y_test, y_test_pred)
precision = precision_score(y_test, y_test_pred)
recall = recall_score(y_test, y_test_pred)
f1 = f1_score(y_test, y_test_pred)
conf_matrix = confusion_matrix(y_test, y_test_pred)

print(f"Accuracy: {accuracy:.2f}")
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1 Score: {f1:.2f}")
print("\nConfusion Matrix:")
print(conf_matrix)
print(classification_report(y_test, y_test_pred))
# Out:
# Accuracy: 0.93
# Precision: 0.91
# Recall: 0.95
# F1 Score: 0.93
#
# Confusion Matrix:
# [[20  2]
#  [ 1 21]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.91      0.93        22
#            1       0.91      0.95      0.93        22
#
#     accuracy                           0.93        44
#    macro avg       0.93      0.93      0.93        44
# weighted avg       0.93      0.93      0.93        44

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_curve, auc, RocCurveDisplay
import numpy as np
import matplotlib.pyplot as plt

# Initialize the model
RF = RandomForestClassifier(max_depth=10, n_estimators=50, random_state=40)

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=40)

# Variables to store results
tprs = []
aucs = []
mean_fpr = np.linspace(0, 1, 100)

# Create the plot
fig, ax = plt.subplots(figsize=(7, 4))

# Perform cross-validation
for i, (train_idx, test_idx) in enumerate(cv.split(X_res, y_res)):
    # Split data
    X_train, X_test = X_res[train_idx], X_res[test_idx]
    y_train, y_test = y_res[train_idx], y_res[test_idx]

    # Fit the model
    RF.fit(X_train, y_train)

    # Get probabilities for the positive class
    y_test_proba = RF.predict_proba(X_test)[:, 1]

    # Compute ROC curve and AUC
    fpr, tpr, _ = roc_curve(y_test, y_test_proba)
    roc_auc = auc(fpr, tpr)
    aucs.append(roc_auc)

    # Interpolate true positive rates
    interp_tpr = np.interp(mean_fpr, fpr, tpr)
    interp_tpr[0] = 0.0
    tprs.append(interp_tpr)

    # Plot the ROC curve for this fold
    ax.plot(fpr, tpr, alpha=0.3, label=f"Fold {i} ROC (AUC = {roc_auc:.2f})")

# Plot the chance line
ax.plot([0, 1], [0, 1], linestyle="--", color="gray", label="Chance", lw=2)

# Calculate and plot the mean ROC curve
mean_tpr = np.mean(tprs, axis=0)
mean_tpr[-1] = 1.0
mean_auc = auc(mean_fpr, mean_tpr)
std_auc = np.std(aucs)

ax.plot(
    mean_fpr,
    mean_tpr,
    color="b",
    label=r"Mean ROC (AUC = %0.2f ± %0.2f)" % (mean_auc, std_auc),
    lw=2,
    alpha=0.8,
)

# Fill between the standard deviation bounds
std_tpr = np.std(tprs, axis=0)
tprs_upper = np.minimum(mean_tpr + std_tpr, 1)
tprs_lower = np.maximum(mean_tpr - std_tpr, 0)
ax.fill_between(
    mean_fpr,
    tprs_lower,
    tprs_upper,
    color="gray",
    alpha=0.2,
    label=r"$\pm$ 1 std. dev.",
)

# Customize plot
ax.set(
    xlabel="False Positive Rate",
    ylabel="True Positive Rate",
    xlim=[-0.05, 1.05],
    ylim=[-0.05, 1.05],
    title="ROC for CBGs-Stage 1 with Cross-Validation",
)
ax.legend(loc="lower right")
plt.savefig("ROC_1.png", dpi=1000)
plt.show()

# %%
ML1 = pd.DataFrame(common, columns=['ensembl_gene_id'])
ML1['Stage'] = 'Stage1'
ML1.to_csv('ML1.csv', index=False)
